# %%
#import libraries
from PIL import Image
import numpy as np
from numpy import asarray
from skimage import  io, filters,feature

# %%
#load image
img = Image.open('ball.jpg')

# %%
#analyse image
print(img.size)
print(img.format)
print(img.mode)
# Out:
# (2999, 1999)
# JPEG
# RGB

# %%
#image to numpy array
numpyimg = asarray(img)

print(numpyimg)
# Out:
# [[[ 32  68  68]
#   [ 32  68  68]
#   [ 32  68  68]
#   ...
#   [ 30  74  75]
#   [ 30  74  75]
#   [ 30  74  75]]
#
#  [[ 31  67  67]
#   [ 31  67  67]
#   [ 31  67  67]
#   ...
#   [ 30  74  75]
#   [ 30  74  75]
#   [ 29  73  74]]
#
#  [[ 31  67  67]
#   [ 31  67  67]
#   [ 31  67  67]
#   ...
#   [ 30  74  75]
#   [ 29  73  74]
#   [ 29  73  74]]
#
#  ...
#
#  [[147  75  51]
#   [147  75  51]
#   [147  75  51]
#   ...
#   [126  65  60]
#   [126  65  60]
#   [126  65  60]]
#
#  [[147  75  51]
#   [147  75  51]
#   [147  75  51]
#   ...
#   [126  65  60]
#   [127  66  61]
#   [127  66  61]]
#
#  [[147  75  51]
#   [147  75  51]
#   [147  75  51]
#   ...
#   [127  67  59]
#   [127  67  59]
#   [127  67  59]]]

# %%
#view image
io.imshow(numpyimg)
io.show()

# %%
#rgb to grayscale
from skimage import color
gray= color.rgb2gray(numpyimg)
io.imshow(gray)
io.show()

# %%
#Edge detection roberts
edge_roberts = filters.roberts(gray)
io.imshow(edge_roberts,cmap=plt.cm.gray)

# %%
#edge detection sobel
edge_sobel = filters.sobel(gray)
io.imshow(edge_sobel)

# %%
# filter sobel
filter0 = filters.sobel(img)
io.imshow(filter0)
io.show()

# %%
# filter laplace
filter1=filters.laplace(img)
io.imshow(filter1)
io.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
#filter gaussian
filter2=filters.gaussian(numpyimg)
io.imshow(filter2)
io.show()
# Out:
# <ipython-input-42-be50e8fb2814>:1: RuntimeWarning: Images with dimensions (M, N, 3) are interpreted as 2D+RGB by default. Use `multichannel=False` to interpret as 3D image with last dimension of length 3.
#   filter2=filters.gaussian(numpyimg)
